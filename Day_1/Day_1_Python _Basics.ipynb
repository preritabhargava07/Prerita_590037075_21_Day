# %% [markdown]
# # DAY 01 / PYTHON BASICS
#
# 'variables' · 'data types' · 'print()' · 'reassignment' · 'type conversion' · 'operators'
#
# ---
#
# *20 problems. One notebook.*
#
# > Today I'm building the foundation — understanding how Python stores, identifies, changes, and works with values.
#
# ---

# %% [markdown]
# ### Q1- Variables and Output
# **Task:** Create a variable called 'name', store any name in it , and print its value.

# %%
name = "Prerita Bhargava"
print(name)
# Out:
# Prerita Bhargava

# %% [markdown]
# ### Q2 - Printing Multiple Variables
# **Task:** Store age and city in seperate variables and print both values using a single "print()" statement.

# %%
age = 25
city = "Dehradun"
print(age,city)
# Out:
# 25 Dehradun

# %% [markdown]
# ### Q3 - Identifying data types
# **Task:** Identifying the data type of each given variable.

# %%
a= 10
b = 10.5
c = "10"
d = True 
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ### Q4 - Checking a Data Type
# **Task:** use python to check the data type of 'price'

# %%
price = 499.99
print(type(price))
# Out:
# <class 'float'>

# %% [markdown]
# ### Q5 - variable Reassignment
# **Task:** Predict the output when the value of a variable is reassignment

# %%
x= 10 
print (x)
x = 20
print (x)
# Out:
# 10
# 20

# %% [markdown]
# ### Q6 - printing Different Data Types
# **Task:** Predict the output when a string and an integer are printed together

# %%
name = "Python"
version = 3
print (name, version)
# Out:
# Python 3

# %% [markdown]
# ### Q7 - Variable Naming Rules
# **Task:** Find and correct the error in the variable name.

# %%
student_name = "Rahul"
print (student_name)
# Out:
# Rahul

# %% [markdown]
# ### Q8 - Valid variable Name
# **Task:** Indentify which variable names are valid in python

# %%
Student_name ="valid"
student2 = "Valid"
_score = "Valid"
print(student_name)
print(student2)
print(_score)
# Out:
# Rahul
# Valid
# Valid

# %% [markdown]
# ### Q9 - Basic Operators
# **Task:** Predict the output of addition and multiplication using two variables.

# %%
a = 5
b = 3
print( a + b)
print (a * b)
# Out:
# 8
# 15

# %% [markdown]
# ### Q10 - Applying Variables to a Calculation
# **Task:** calculate the area of a rectangle using 'length' and 'width'

# %%
length = 10
width = 5
area = length * width
print (area)
# Out:
# 50

# %% [markdown]
# ### Q11 - String Concatenation
# **Task:** Predict what happens when two strings containing numbers are added together.

# %%
x = "10"
y = "20"
print (x + y)
# Out:
# 1020

# %% [markdown]
# ### Q12 - Type Conversion
# **Task:** Convert a string into an integer and add '5' to it.

# %%
number = "25"
number = int (number)
result = number + 5
print (result)
# Out:
# 30

# %% [markdown]
# ### Q13 _ Integer to Float
# ** Task:** Predict the output after converting an integer into a float.

# %%
x = 10 
y = float(x)
print (y)
print (type(y))
# Out:
# 10.0
# <class 'float'>

# %% [markdown]
# ### Q14 Float to Integer
# **Task:** Convert the floating point value into an intger and print the result.

# %%
price = 99.5
price = int(price)
print(price)
# Out:
# 99

# %% [markdown]
# ### Q15 - division Operators
# **Task:** Compare normal divison, floor divison, and the modulas operator.

# %%
a = 10
b = 3
print (a/b)
print (a//b)
print (a%b)
# Out:
# 3.3333333333333335
# 3
# 1

# %% [markdown]
# ### Q16 - Multiple assignment
# ** Task:** Assign values to three variables in a single line.

# %%
a, b, c = 10, 20, 30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ### Q17 - Updating a variable
# **Task:** Predict the final value after updating a variable multiple times.

# %%
x = 5
x = x + 10
x = x * 2
print(x)
# Out:
# 30

# %% [markdown]
# ### Q18 - Calculating total price
# **Task:** Use price and quantity to calculate the total cost

# %%
item = "Laptop"
price = 50000
quantity = 2
total_price = price * quantity
print (total_price)
# Out:
# 100000

# %% [markdown]
# ### Q19 - Fixing a type error
# **Task:** Correct the code so that '1' can be added to the given age

# %%
age = "20"
next_age = int(age)+ 1
print(next_age)
# Out:
# 21

# %% [markdown]
# ### Q20 - Final Challenge - Student Report
# **Task:** create a studnet record, calculate the total and average marks, and display the final results

# %%
student_name = "Prerita"
age = 19
Course = "Python Programming"
subject_1 = 85
subject_2 = 78
subject_3 = 92
total_marks = subject_1 + subject_2 + subject_3
average_makrs = total_marks / 3
print ("Student:", student_name)
print ("Age:", age)
print ("Course:", Course)
print ("Total Marks:", total_marks)
print ("Average Marks:", average_makrs)
# Out:
# Student: Prerita
# Age: 19
# Course: Python Programming
# Total Marks: 255
# Average Marks: 85.0
