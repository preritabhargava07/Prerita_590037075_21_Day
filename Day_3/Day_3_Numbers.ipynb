# %% [markdown]
# # DAY 03 | NUMBERS & OPERATORS
# `Arithmetic` . `division` . `powers` . `built-in functions` . `math module` . `rounding`
#
# ---
#
# **Focus:** Using Python numbers and operators to perform Calculations and Solve Practical Numerical problems.

# %% [markdown]
# ### Q1 - Basic Arithmetic Operators
# **Task:** Perform addition, subtarction and multiplication on two numbers.

# %%
print(10 + 3, 10 - 3, 10 * 3)
